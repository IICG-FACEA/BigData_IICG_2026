# %%
import requests
from bs4 import BeautifulSoup

# Configuraci n de entrada
url = "https://books.toscrape.com/"
headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen

# 1. Petici n al servidor
respuesta = requests.get(url, headers=headers)

# 2. Convertir el HTML en un objeto de Python
sopa = BeautifulSoup(respuesta.text, "html.parser")

# 3. Buscar los datos (Ejemplo: buscar todos los t tulos)
# Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste
resultados = sopa.find_all("article", class_="product_pod")

# 4. Mostrar en pantalla
for dato in resultados:
    titulo =dato.h3.a["title"]
    precio = dato.find("p", class_="price_color").text.strip
    estrellas = dato.find ("p", class_="star-rating")["class"][1]
    
    print(f"Encontrado: {titulo} | Precio: {precio} | Estrella: {estrellas} ")
# Out:
# Encontrado: A Light in the Attic | Precio: <built-in method strip of str object at 0x76621390a240> | Estrella: Three
# Encontrado: Tipping the Velvet | Precio: <built-in method strip of str object at 0x766213f97a50> | Estrella: One
# Encontrado: Soumission | Precio: <built-in method strip of str object at 0x7662139094d0> | Estrella: One
# Encontrado: Sharp Objects | Precio: <built-in method strip of str object at 0x766213fd3eb0> | Estrella: Four
# Encontrado: Sapiens: A Brief History of Humankind | Precio: <built-in method strip of str object at 0x76621390a240> | Estrella: Five
# Encontrado: The Requiem Red | Precio: <built-in method strip of str object at 0x766213f97a50> | Estrella: One
# Encontrado: The Dirty Little Secrets of Getting Your Dream Job | Precio: <built-in method strip of str object at 0x7662139094d0> | Estrella: Four
# Encontrado: The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull | Precio: <built-in method strip of str object at 0x766213fd3eb0> | Estrella: Three
# Encontrado: The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics | Precio: <built-in method strip of str object at 0x76621390a240> | Estrella: Four
# Encontrado: The Black Maria | Precio: <built-in method strip of str object at 0x766213f97a50> | Estrella: One
# Encontrado: Starving Hearts (Triangular Trade Trilogy, #1) | Precio: <built-in method strip of str object at 0x7662139094d0> | Estrella: Two
# Encontrado: Shakespeare's Sonnets | Precio: <built-in method strip of str object at 0x766213fd3eb0> | Estrella: Four
# Encontrado: Set Me Free | Precio: <built-in method strip of str object at 0x76621390a240> | Estrella: Five
# Encontrado: Scott Pilgrim's Precious Little Life (Scott Pilgrim #1) | Precio: <built-in method strip of str object at 0x766213f97a50> | Estrella: Five
# Encontrado: Rip it Up and Start Again | Precio: <built-in method strip of str object at 0x7662139094d0> | Estrella: Five
# Encontrado: Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991 | Precio: <built-in method strip of str object at 0x766213fd3eb0> | Estrella: Three
# Encontrado: Olio | Precio: <built-in method strip of str object at 0x76621390a240> | Estrella: One
# Encontrado: Mesaerion: The Best Science Fiction Stories 1800-1849 | Precio: <built-in method strip of str object at 0x766213f97a50> | Estrella: One
# Encontrado: Libertarianism for Beginners | Precio: <built-in method strip of str object at 0x7662139094d0> | Estrella: Two
# Encontrado: It's Only the Himalayas | Precio: <built-in method strip of str object at 0x766213fd3eb0> | Estrella: Two

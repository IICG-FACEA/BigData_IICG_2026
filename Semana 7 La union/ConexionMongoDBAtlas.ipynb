# %%
from pymongo import MongoClient
import certifi

uri = "mongodb://nicolegarcia_db_user:Ternurines123@ac-iq19sqr-shard-00-00.uia9vsi.mongodb.net:27017,ac-iq19sqr-shard-00-01.uia9vsi.mongodb.net:27017,ac-iq19sqr-shard-00-02.uia9vsi.mongodb.net:27017/?ssl=true&replicaSet=atlas-t7etb5-shard-0&authSource=admin&appName=Cluster0"

client = MongoClient(
    uri,
    tlsCAFile=certifi.where(),
    serverSelectionTimeoutMS=5000
)

try:
    print(client.server_info())
    print(" Conexión exitosa")
except Exception as e:
    print(" Error:", e)
# Out:
# {'version': '8.0.23', 'gitVersion': 'ccf0d81588377542f00eeecf1b1ffbc095b1eeff', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 23, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1779057650, 15), 'signature': {'hash': b'\xd9\xe5\xb0"\xe4+\x9f3\xa1z\x9e{m\xc9Y\x91q\x80K\xb8', 'keyId': 7582612753605459981}}, 'operationTime': Timestamp(1779057650, 15)}
#  Conexión exitosa

# %%
db = client["prueba"]
coleccion = db["personas"]

coleccion.insert_one({"nombre": "Jesús", "edad": 60})
print(list(coleccion.find()))
# Out:
# [{'_id': ObjectId('69ea44846824a40b76b1d08e'), 'nombre': 'Jesús', 'edad': 60}, {'_id': ObjectId('69ea4a576824a40b76b1d08f'), 'nombre': 'Jesús', 'edad': 60}, {'_id': ObjectId('69ea4a686824a40b76b1d090'), 'nombre': 'Jesús3', 'edad': 40}]

# %%
from pymongo import MongoClient
import certifi

uri = "mongodb://nicolegarcia_db_user:Ternurines123@ac-iq19sqr-shard-00-00.uia9vsi.mongodb.net:27017,ac-iq19sqr-shard-00-01.uia9vsi.mongodb.net:27017,ac-iq19sqr-shard-00-02.uia9vsi.mongodb.net:27017/?ssl=true&replicaSet=atlas-t7etb5-shard-0&authSource=admin&appName=Cluster0"

client = MongoClient(
    uri,
    tlsCAFile=certifi.where(),
    serverSelectionTimeoutMS=5000
)

try:
    print(client.server_info())
    print(" Conexión exitosa")
except Exception as e:
    print(" Error:", e)
# Out:
# {'version': '8.0.23', 'gitVersion': 'ccf0d81588377542f00eeecf1b1ffbc095b1eeff', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 23, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1778805259, 41), 'signature': {'hash': b' \x82+\x18E\xe6\xb1\xca\x13\x86k\x1aR\x86%\xbf\xf4\xccCw', 'keyId': 7582612753605459981}}, 'operationTime': Timestamp(1778805259, 41)}
#  Conexión exitosa

# %%
from pymongo import MongoClient
import certifi

uri = "mongodb://nicolegarcia_db_user:Ternurines123@ac-iq19sqr-shard-00-00.uia9vsi.mongodb.net:27017,ac-iq19sqr-shard-00-01.uia9vsi.mongodb.net:27017,ac-iq19sqr-shard-00-02.uia9vsi.mongodb.net:27017/?ssl=true&replicaSet=atlas-t7etb5-shard-0&authSource=admin&appName=Cluster0"

client = MongoClient(
    uri,
    tlsCAFile=certifi.where(),
    serverSelectionTimeoutMS=5000
)

try:
    print(client.server_info())
    print("Conexión exitosa")
except Exception as e:
    print("Error:", e)

db = client["prueba"]
coleccion = db["personas"]

coleccion.insert_one({"nombre": "Vannessa", "edad": 30})
print(list(coleccion.find()))
# Out:
# {'version': '8.0.23', 'gitVersion': 'ccf0d81588377542f00eeecf1b1ffbc095b1eeff', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 23, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1778805394, 1), 'signature': {'hash': b"y(\x0b\xf8HPt\xdc\xe5'L\xe4j;\xcc\xcch\xa1\xe8\x16", 'keyId': 7582612753605459981}}, 'operationTime': Timestamp(1778805394, 1)}
# Conexión exitosa
# ...

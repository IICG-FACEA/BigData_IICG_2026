# %%
print("Hola, funciona Jupyter")
# Out:
# Hola, funciona Jupyter

# %%
import requests
import pandas as pd

try:
    url = "https://api.exchangerate-api.com/v4/latest/USD"
    respuesta = requests.get(url)
    datos = respuesta.json()

    df = pd.DataFrame(datos['rates'].items(), columns=['Moneda', 'Valor'])
    print("Conexión exitosa")
    print(df.head())

except Exception as e:
    print(f"Error: {e}")
# Out:
# Conexión exitosa
#   Moneda   Valor
# 0    USD    1.00
# 1    AED    3.67
# 2    AFN   63.00
# 3    ALL   83.13
# 4    AMD  377.58

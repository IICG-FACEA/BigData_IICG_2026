# %%
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service

os.environ["DISPLAY"] = ":99"
os.environ["XDG_RUNTIME_DIR"] = "/tmp/runtime-root"

options = Options()
options.binary_location = "/usr/bin/google-chrome"
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--disable-gpu")
options.add_argument("--disable-software-rasterizer")
options.add_argument("--window-size=1366,768")
options.add_argument("--remote-debugging-port=9222")

driver = webdriver.Chrome(service=Service(), options=options)
driver.get("https://www.google.com")
print(driver.title)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[2], line 18
#      15 options.add_argument("--window-size=1366,768")
#      16 options.add_argument("--remote-debugging-port=9222")
# ---> 18 driver = webdriver.Chrome(service=Service(), options=options)
#      19 driver.get("https://www.google.com")
#      20 print(driver.title)
#
# File /opt/conda/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File /opt/conda/lib/python3.11/site-packages/selenium/webdriver/chromium/webdriver.py:66, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      57 executor = ChromiumRemoteConnection(
#      58     remote_server_addr=self.service.service_url,
#      59     browser_name=browser_name,
#    (...)
#      62     ignore_proxy=self.options._ignore_local_proxy,
#      63 )
#      65 try:
# ---> 66     super().__init__(command_executor=executor, options=self.options)
#      67 except Exception:
#      68     self.quit()
#
# File /opt/conda/lib/python3.11/site-packages/selenium/webdriver/common/webdriver.py:25, in LocalWebDriver.__init__(self, *args, **kwargs)
#      24 def __init__(self, *args, **kwargs):
# ---> 25     super().__init__(*args, **kwargs)
#      26     self._is_remote = False
#
# File /opt/conda/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:274, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     272 self._authenticator_id = None
#     273 self.start_client()
# --> 274 self.start_session(capabilities)
#     275 self._fedcm = FedCM(self)
#     277 self._websocket_connection: WebSocketConnection | None = None
#
# File /opt/conda/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:370, in WebDriver.start_session(self, capabilities)
#     368 caps = _create_caps(capabilities)
#     369 try:
# --> 370     response = self.execute(Command.NEW_SESSION, caps)["value"]
#     371     self.session_id = response.get("sessionId")
#     372     self.caps = response.get("capabilities")
#
# File /opt/conda/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:450, in WebDriver.execute(self, driver_command, params)
#     447 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     449 if response:
# --> 450     self.error_handler.check_response(response)
#     451     response["value"] = self._unwrap_value(response.get("value", None))
#     452     return response
#
# File /opt/conda/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: Chrome instance exited. Examine ChromeDriver verbose log to determine the cause.; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#sessionnotcreatedexception
# Stacktrace:
# #0 0x615eb2d96afa <unknown>
# #1 0x615eb2798265 <unknown>
# #2 0x615eb27d4f3b <unknown>
# #3 0x615eb27cfc09 <unknown>
# #4 0x615eb281ff9e <unknown>
# #5 0x615eb281f68c <unknown>
# #6 0x615eb27de5cf <unknown>
# #7 0x615eb27df391 <unknown>
# #8 0x615eb2d5bfdb <unknown>
# #9 0x615eb2d5ef9d <unknown>
# #10 0x615eb2d48798 <unknown>
# #11 0x615eb2d5fb30 <unknown>
# #12 0x615eb2d2f210 <unknown>
# #13 0x615eb2d83d48 <unknown>
# #14 0x615eb2d83f18 <unknown>
# #15 0x615eb2d9556e <unknown>
# #16 0x79718506cac3 <unknown>

# %%
# !google-chrome --version
# !chromedriver --version
# Out:
# Google Chrome 147.0.7727.55
# /bin/bash: line 1: chromedriver: command not found

# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager


# Configuración del navegador
options = Options()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--disable-gpu")

driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
)

paginas_visitadas = 1

try:
    # Página inicial
    driver.get("https://books.toscrape.com/")

    print(f"Página {paginas_visitadas}: {driver.current_url}")

    while True:
        try:
            # Buscar el botón "next"
            boton_siguiente = driver.find_element(
                By.XPATH,
                "//li[@class='next']/a"
            )

            # Ir a la siguiente página
            boton_siguiente.click()

            # Esperar a que cargue
            time.sleep(2)

            paginas_visitadas += 1

            print(f"Página {paginas_visitadas}: {driver.current_url}")

        except Exception:
            print("\nNo hay más páginas disponibles.")
            break

    print(f"\nTotal de páginas recorridas: {paginas_visitadas}")

finally:
    driver.quit()
    print("Navegador cerrado.")
# Out:
# Página 1: https://books.toscrape.com/
# Página 2: https://books.toscrape.com/catalogue/page-2.html
# Página 3: https://books.toscrape.com/catalogue/page-3.html
# Página 4: https://books.toscrape.com/catalogue/page-4.html
# Página 5: https://books.toscrape.com/catalogue/page-5.html
# Página 6: https://books.toscrape.com/catalogue/page-6.html
# Página 7: https://books.toscrape.com/catalogue/page-7.html
# Página 8: https://books.toscrape.com/catalogue/page-8.html
# Página 9: https://books.toscrape.com/catalogue/page-9.html
# Página 10: https://books.toscrape.com/catalogue/page-10.html
# Página 11: https://books.toscrape.com/catalogue/page-11.html
# Página 12: https://books.toscrape.com/catalogue/page-12.html
# Página 13: https://books.toscrape.com/catalogue/page-13.html
# Página 14: https://books.toscrape.com/catalogue/page-14.html
# Página 15: https://books.toscrape.com/catalogue/page-15.html
# Página 16: https://books.toscrape.com/catalogue/page-16.html
# ...

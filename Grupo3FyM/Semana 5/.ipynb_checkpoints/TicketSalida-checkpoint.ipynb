# %%
from pyspark.sql import functions as F

# CONSULTA DE SALIDA: Resumen de integridad por Categoría
ticket_salida = df.filter(F.col("grupo") == NOMBRE_GRUPO) \
    .groupby("categoría") \
    .agg(
        F.count("item").alias("total_libros"),
        F.round(F.avg("valor"), 2).alias("precio_medio"),
        F.max("fecha_captura").alias("ultima_sincronizacion")
    )

print(f"--- TICKET DE SALIDA: {NOMBRE_GRUPO} ---")
ticket_salida.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 from pyspark.sql import functions as F
#       4 # CONSULTA DE SALIDA: Resumen de integridad por Categoría
# ----> 5 ticket_salida = df.filter(F.col("grupo") == NOMBRE_GRUPO) \
#       6     .groupby("categoría") \
#       7     .agg(
#       8         F.count("item").alias("total_libros"),
#       9         F.round(F.avg("valor"), 2).alias("precio_medio"),
#      10         F.max("fecha_captura").alias("ultima_sincronizacion")
#      11     )
#      13 print(f"--- TICKET DE SALIDA: {NOMBRE_GRUPO} ---")
#      14 ticket_salida.show()
#
# NameError: name 'df' is not defined

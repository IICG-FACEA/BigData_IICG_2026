# %%
from pymongo import MongoClient
import certifi

uri = "mongodb+srv://rodrigoortega_db_user:ucn12@cluster0.uia9vsi.mongodb.net/BigData_UCN?retryWrites=true&w=majority"

client = MongoClient(
    uri,
    tlsCAFile=certifi.where(),
    serverSelectionTimeoutMS=5000
)

try:
    print(client.server_info())
    print(" Conexión exitosa")
except Exception as e:
    print(" Error:", e)
# Out:
# {'version': '8.0.23', 'gitVersion': 'ccf0d81588377542f00eeecf1b1ffbc095b1eeff', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 23, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1778728997, 36), 'signature': {'hash': b'\xae\x16\xa1\x8d\x03\xfaSi;B\xa8o\x88\xb6\xdf\xd1\x028T\x9e', 'keyId': 7582612753605459981}}, 'operationTime': Timestamp(1778728997, 36)}
#  Conexión exitosa

# %%
db = client["prueba"]
coleccion = db["personas"]

coleccion.insert_one({"nombre": "Jesús", "edad": 60})
print(list(coleccion.find()))
# Out:
# [{'_id': ObjectId('69ffda9563346e75d056eaa0'), 'nombre': 'Jesús', 'edad': 60}, {'_id': ObjectId('6a0515ca928fcf0585db56d8'), 'nombre': 'Jesús', 'edad': 60}, {'_id': ObjectId('6a051ba2262f2b0d90d843ba'), 'nombre': 'Jesús', 'edad': 60}, {'_id': ObjectId('6a053d5b3325a4c0b1ed0ca0'), 'nombre': 'Jesús', 'edad': 60}, {'_id': ObjectId('6a0540230f5271b019148dd5'), 'nombre': 'Jesús', 'edad': 60}]

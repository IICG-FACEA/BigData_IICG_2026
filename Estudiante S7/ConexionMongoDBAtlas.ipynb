# %%
from pymongo import MongoClient
import certifi

uri = "mongodb+srv://yhadfeg_db_user:3192Yahima@cluster0.8pbh7yw.mongodb.net/?retryWrites=true&w=majority"

client = MongoClient(
    uri,
    tlsCAFile=certifi.where(),
    serverSelectionTimeoutMS=5000
)

try:
    print(client.server_info())
    print(" Conexión exitosa")
except Exception as e:
    print(" Error:", e)
# Out:
# {'version': '8.0.21', 'gitVersion': 'e67138ffda9f90b59531128bc43678bb5ad105ed', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 21, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1776964799, 1), 'signature': {'hash': b'A\x88\x03~\x01\xfaK\x1a\xa8\xf5]\xd6\x11.\xdeB\xb6w\x9eL', 'keyId': 7568907852266340354}}, 'operationTime': Timestamp(1776964799, 1)}
#  Conexión exitosa

# %%
db = client["prueba"]
coleccion = db["personas"]

coleccion.insert_one({"nombre": "Yahima", "edad": 40})
print(list(coleccion.find()))
# Out:
# [{'_id': ObjectId('69ea44846824a40b76b1d08e'), 'nombre': 'Jesús', 'edad': 60}, {'_id': ObjectId('69ea4a576824a40b76b1d08f'), 'nombre': 'Jesús', 'edad': 60}, {'_id': ObjectId('69ea4a686824a40b76b1d090'), 'nombre': 'Jesús3', 'edad': 40}, {'_id': ObjectId('69ea559e3937e2bb3ae378f2'), 'nombre': 'Yahima', 'edad': 40}]

# %%
import requests
from bs4 import BeautifulSoup

#Configuracion de entrada
url = "https://www.pisos.com/venta/pisos-madrid/2/"
headers = {"User-Agent": "Mozilla/5.0"}

#Peticion al servidor
respuesta = requests.get(url, headers=headers)

#Convertir el HTML en un objeto de python
sopa = BeautifulSoup(respuesta.text, 'html.parser')

#Buscar los datos
resultados = sopa.find_all('div', id="61737625941.992099")

#Mostrar en pantalla
for dato in resultados:
    print(f"Encontrado: {dato.text.strip()}")
# Out:
# Encontrado: 1/17
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Reformado
#
#
#
#
#
#
#                         865.000 €
#
#
#
#
#
# Piso en calle de Medellín, 10
# Trafalgar (Distrito Chamberí. Madrid Capital)
#
#
#
# 2 habs.
# 2 baños
# 88 m²
# 1ª planta
#
#
#
# Preciosa vivienda con reforma de diseño junto a la c/ santa engracia, a tan solo 3 minutos a pie de la glorieta del pintor sorolla...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp

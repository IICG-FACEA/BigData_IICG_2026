# %% [markdown]
# # 🐶 Proyecto Big Data: Inteligencia de Mercado en Productos para Mascotas
#
#
# ### Contexto del Proyecto
#
# El mercado de productos para mascotas ha experimentado un crecimiento sostenido durante los últimos años. Las empresas del sector necesitan comprender continuamente:
#
# - cómo cambian los precios,
# - qué marcas dominan el mercado,
# - cuáles productos poseen mejor valoración,
# - qué formatos ofrecen mejor relación precio/calidad,
# - y cómo se segmentan los consumidores y productos dentro del ecosistema digital.
#
# Actualmente muchas organizaciones toman estas decisiones de forma manual, revisando páginas web una por una, sin automatización ni almacenamiento histórico de datos, lo que dificulta identificar tendencias y patrones relevantes para la toma de decisiones eégicas.
#
# ---
#
# # 🎯 Objetivo del Proyecto
#
# Desarrollar un pipeline de Big Data capaz de:
#
# - Capturar información desde sitios web relacionados con productos para mascotas.
# - Almacenar grandes volúmenes de datos en MongoDB Atlas.
# - Procesar y limpiar datos utilizando Apache Spark.
# - Realizar análisis exploratorio de datos (EDA).
# - Aplicar técnicas de segmentación mediante Machine Learning.
# - Generar conocimiento útil para apoyar denes organizacionales.
#
# ---
#
# # ❓ Pregunta de Negocio
#
# ## ¿Cómo se segmenta el mercado de productos para mascotas según variables como:
#
# - precio,
# - marca,
# - formato,
# - rating,
# - oones,
# - y relación precio/calidad?
#
# ---
#
# # 📊 Objetivos Analíticos
#
# Durante el desarrollo del proyecto se buscará responder preguntas como:
#
# - ¿Qué marcas presentan precios más elevados?
# - ¿Qué productos tienen mejor valoración por parte de los usuarios?
# - ¿Existen productos sobrevalorados o subvalorados?
# - ¿Qué segmentos de mercado pueden identificarse?
# - ¿Qué características poseen los productos premium?
# - ¿Cómo varía el precio según formato o cría?
# - ¿Existe relación entre precio y rating?
#
#
# ---
#
# # ⚙️ Pipeline Tecnológico del Proyecto
#
# El flujo general del proyecto será:
#
# ```text
# Sitio Web (Tiendanimal)
#             ↓
# Scraping Web
#             ↓
# MongoDB Atlas (Raw Data)
#             ↓
# Apache Spark
#             ↓
# EDA y Limpieza
#             ↓
# Analisis Exploratorio
#             ↓
# Clustering y Machine Learning
#             ↓
# Generación de conocimiento

# %%
# !python scraperss/scraper_tiendanimal.py
# Out:
# Inicio del pipeline Scraper / Raw Data
# Conexión exitosa con MongoDB Atlas
# Base de datos utilizada: MascotasDB
# Colección utilizada: productos_raw
#
# Procesando página 1
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=1
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 32
#
# Procesando página 2
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=2
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 64
#
# Procesando página 3
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=3
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 96
#
# Procesando página 4
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=4
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 128
#
# Procesando página 5
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=5
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 160
#
# Procesando página 6
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=6
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 192
#
# Procesando página 7
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=7
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 224
#
# Procesando página 8
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=8
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 256
#
# Procesando página 9
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=9
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 288
#
# Procesando página 10
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=10
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 320
#
# Procesando página 11
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=11
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 352
#
# Procesando página 12
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=12
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 384
#
# Procesando página 13
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=13
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 416
#
# Procesando página 14
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=14
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 448
#
# Procesando página 15
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=15
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 480
#
# Procesando página 16
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=16
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 512
#
# Procesando página 17
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=17
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 544
#
# Procesando página 18
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=18
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 576
#
# Procesando página 19
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=19
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 608
#
# Procesando página 20
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=20
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 640
#
# Procesando página 21
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=21
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 672
#
# Procesando página 22
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=22
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 704
#
# Procesando página 23
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=23
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 736
#
# Procesando página 24
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=24
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 768
#
# Procesando página 25
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=25
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 800
#
# Procesando página 26
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=26
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 832
#
# Procesando página 27
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=27
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 864
#
# Procesando página 28
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=28
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 896
#
# Procesando página 29
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=29
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 928
#
# Procesando página 30
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=30
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 960
#
# Procesando página 31
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=31
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 992
#
# Procesando página 32
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=32
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 1024
#
# Procesando página 33
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=33
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 1056
#
# Procesando página 34
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=34
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 1088
#
# Procesando página 35
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=35
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 1120
#
# Procesando página 36
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=36
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 1152
#
# Procesando página 37
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=37
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 1184
#
# Procesando página 38
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=38
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 1216
#
# Procesando página 39
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=39
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 1248
#
# Procesando página 40
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=40
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 1280
#
# Procesando página 41
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=41
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.
#
# Tarjetas de producto encontradas: 32
# Productos acumulados: 1312
#
# Procesando página 42
# URL: https://www.tiendanimal.es/perros/pienso-para-perros/?page=42
# HTML obtenido correctamente
# Posible bloqueo detectado. Puede requerir intervención humana.
#
# === MODO INTERVENCIÓN MANUAL ACTIVADO ===
# Abra el navegador visual Docker/noVNC en:
# http://localhost:6080/vnc.html
#
# Dentro del navegador:
# - Resuelva captcha si aparece
# - Espere a que cargue la página
# - No cierre la ventana del navegador
#
# El sistema esperará 30 segundos para la validación manual.

# %% [markdown]
# # Crear SparkSession

# %%
from pyspark.sql import SparkSession


# URI MongoDB Atlas
MONGO_URI = "mongodb+srv://yhadfeg_db_user:3192Yahima@cluster0.8pbh7yw.mongodb.net/ProyectoSemana9?retryWrites=true&w=majority"

# Crear SparkSession
spark = SparkSession.builder \
    .appName("EDA_Mascotas_Semana9") \
    .config(
        "spark.jars.packages",
        "org.mongodb.spark:mongo-spark-connector_2.12:10.1.1"
    ) \
    .getOrCreate()

print("Spark iniciado correctamente")

# %%
import requests
from bs4 import BeautifulSoup

# Configuraci n de entrada
url = "https://www.python.org/jobs/"
headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen

# 1. Petici n al servidor
respuesta = requests.get(url, headers=headers)

# 2. Convertir el HTML en un objeto de Python
sopa = BeautifulSoup(respuesta.text, 'html.parser')

# 3. Buscar los datos (Ejemplo: buscar todos los t tulos)
# Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste
resultados = sopa.find_all('div', class_='row')

# 4. Mostrar en pantalla
for dato in resultados:
   print(f"Encontrado: {dato.text.strip()}")
# Out:
# Encontrado: New
# Python Developer - Remote
# 		    DivIHN Integration Inc
#
# Atlanta, US
#
# Cloud, Web, Support, Security
#
# Posted: 06 March 2026
# Developer / Engineer
#
#
#
#
# New
# Senior Python Developer
# 		    Six Feet Up
#
# Remote, USA
#
# Back end, Text Processing
#
# Posted: 05 March 2026
# Developer / Engineer
#
#
#
#
# New
# Senior Python Developer/DevOps Engineer
# 		    Six Feet Up
#
# Remote, (USA only)
#
# Back end, Cloud, DevOps
#
# Posted: 05 March 2026
# Developer / Engineer
#
#
#
#
# New
# Python Tech Lead
# 		    TramCase
#
# Remote, Remote
#
# Back end
#
# Posted: 03 March 2026
# Developer / Engineer
#
#
#
#
# New
# Infrastructure Engineer
# 		    Python Software Foundation
#
# Remote, USA
#
# Back end, Cloud, Database, Front end, Operations, Systems, Web
#
# Posted: 19 February 2026
# Developer / Engineer
#
#
#
#
# Senior Python Engineer (backend focused)
# 		    World Parts Direct
#
# Garland, TX, United States
#
# Back end, Database, Front end, Operations, Systems
#
# Posted: 12 February 2026
# Developer / Engineer
#
#
#
#
# DevOps Engineer-FULLY REMOTE-US, CANADA, EUROPE only
# 		    ActivePrime, Inc.
#
# Mountain View, California, United States
#
# Cloud, DevOps
#
# Posted: 09 February 2026
# Developer / Engineer
#
#
#
#
# Senior Back-End Python Engineer - FULLY REMOTE-WORLDWIDE
# 		    ActivePrime, Inc.
#
# Mountain View, California, United States
#
# Back end
#
# Posted: 09 February 2026
# Developer / Engineer
#
#
#
#
# Senior Full-Stack Engineer (remote)
# 		    AIDAR
#
# Hamburg, Germany
#
# Back end, Front end, Lead, Machine Learning
#
# Posted: 30 January 2026
# Developer / Engineer
#
#
#
#
# Junior Software Engineer
# 		    Mechanize
#
# San Francisco, CA, USA
#
# Back end, Front end
#
# Posted: 28 January 2026
# Developer / Engineer
#
#
#
#
# Junior Full Stack Developer
# 		    Patrick J. McGovern Foundation
#
# Remote, Remote, United States
#
# Back end, Front end
#
# Posted: 28 January 2026
# Developer / Engineer
#
#
#
#
# Senior Python Backend Developer
# 		    SKYCATCHFIRE
#
# Canton, OH, USA
#
# Back end
#
# Posted: 19 January 2026
# Developer / Engineer
#
#
#
#
# Senior Software Engineer
# 		    Aquent
#
# Fully remote, East Coast Preferred, United States
#
# Back end, Cloud, Front end, Machine Learning, Web
#
# Posted: 15 January 2026
# Developer / Engineer
#
#
#
#
# Senior Data Privacy Software Developer
# 		    OpenDP / Harvard University
#
# Cambridge, Massachusetts, United States
#
# Machine Learning, Numeric processing
#
# Posted: 09 January 2026
# Developer / Engineer
#
#
#
#
# Senior Backend Python Developer
# 		    Kanmalai Technologies
#
# Bengaluru, Karnataka, India
#
# Back end
#
# Posted: 08 January 2026
# Developer / Engineer
#
#
#
#
# Senior Python Developer
# 		    Cial Dun & Bradstreet
#
# São Paulo, São  Paulo, Brazil
#
# Back end
#
# Posted: 22 December 2025
# Developer / Engineer
#
#
#
#
# AI Engineer
# 		    Adaptify
#
# Remote, Remote, United Kingdom
#
# Back end, Front end, Machine Learning, Testing, Artificial Intelligence, Prompt Engineering
#
# Posted: 10 December 2025
# Developer / Engineer
#
#
#
#
# Director, Ratings AI
# 		    Fitch Ratings
#
# Toronto, Ontario, Canada
#
# Back end, Cloud, Finance, Front end, Machine Learning, Prototyping
#
# Posted: 05 December 2025
# Developer / Engineer

# %%
import requests
from bs4 import BeautifulSoup

# Configuración de entrada
url = "https://www.pisos.com/venta/pisos-madrid/"
headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen, Le dice al servidor qué tipo de cliente está haciendo la petición, para este caso un navegador
                                        # "Referer": "https://www.google.com/": Le indica al servidor desde qué página aparentemente viene el usuario. 
# 1. Petición al servidor
respuesta = requests.get(url, headers=headers)

# 2. Convertir el HTML en un objeto de Python
sopa = BeautifulSoup(respuesta.text, 'html.parser')

# 3. Buscar los datos (Ejemplo: buscar todos los títulos)
# Cambia 'h2' y 'nombre-de-la-clase' por lo que inspeccionaste
resultados = sopa.find_all('div', class_='ad-preview')

# 4. Mostrar en pantalla
for dato in resultados:
    print(f"Encontrado: {dato.text.strip()}")
# Out:
# Encontrado: 1/41
#
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Exclusivo
#
#
#
#
#
#
#                         699.000 €
#
#
#
#
#
# Piso en Avenida de Pilar Miró, 1
# Centro (Rivas-Vaciamadrid)
#
#
#
# 4 habs.
# 2 baños
# 238 m²
# 1ª planta
#
#
#
# Para clientes que realmente sepan apreciar, no solamente los acabado excepcionales de esta vivienda, si no las calidades construct...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/22
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Nuevo
#
#
#
# TOP
#
#
#
#
#
#
#                     Luminoso
#
#
#
#
#
#
#                         1.170.000 €
#
#
#
#
#
# Piso en calle del General Pardiñas
# Goya (Distrito Barrio de Salamanca. Madrid Capital)
#
#
#
# 2 habs.
# 2 baños
# 83 m²
# 6ª planta
#
#
#
# En pleno corazón del barrio de salamanca, una de las zonas más sólidas, cotizadas y líquidas de madrid.
#
# Se trata de una sexta pla...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/45
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Nuevo
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         835.000 €
#
#
#
#
#
# Piso en calle del Duque de Sesto
# Goya (Distrito Barrio de Salamanca. Madrid Capital)
#
#
#
# 3 habs.
# 2 baños
# 80 m²
# 3ª planta
#
#
#
# Excelente piso en venta, en buen estado, calle de duque de sesto esquina con calle de antónio de acuña muy cerca del parque el ret...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# Encontrado: 1/62
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Nuevo
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         1.190.000 €
#
#
#
#
#
# Piso en calle Gaztambide
# Gaztambide (Distrito Chamberí. Madrid Capital)
#
#
#
# 3 habs.
# 3 baños
# 165 m²
# 4ª planta
#
#
#
# ¿Buscas el equilibrio perfecto entre la elegancia clásica de chamberí y el confort moderno? Alfa rivas casamedida presenta este es...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/28
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Nuevo
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         550.000 €
#
#
#
#
#
# Ático en calle de Caramuel
# Cármenes (Distrito Latina. Madrid Capital)
#
#
#
# 1 hab.
# 1 baño
# 122 m²
#
#
#
# Masterpiso vende atico en calle caramuel esquina concejal francisco josé jiménez martín, 6ª planta con ascensor, 58 m² construidos...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/23
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Nuevo
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         390.000 €
#
#
#
#
#
# Piso en calle de Cartagena
# Guindalera (Distrito Barrio de Salamanca. Madrid Capital)
#
#
#
# 2 habs.
# 1 baño
# 60 m²
# 4ª planta
#
#
#
# Si estás buscando una vivienda con potencial para crear un hogar totalmente a tu medida, este piso puede ser justo lo que necesita...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/28
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Nuevo
#
#
#
# TOP
#
#
#
#
#
#
#                     Calidades superiores
#
#
#
#
#
#
#                         369.000 €
#
#
#
#
#
# Piso en calle de los Andaluces
# Palomeras Sureste (Distrito Puente de Vallecas. Madrid Capital)
#
#
#
# 3 habs.
# 2 baños
# 102 m²
# 4ª planta
#
#
#
# Globalpiso palomeras portazgo ofrece en exclusiva una magnifica vivienda reformada. Sus 102 m² construidos ofrecen espacios amplio...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/33
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             Nuevo
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         440.000 €
#
#
#
#
#
# Piso en Camino de Barajas
# Casco Histórico de Barajas (Distrito Barajas. Madrid Capital)
#
#
#
# 2 habs.
# 1 baño
# 80 m²
# 1ª planta
#
#
#
# **piso en venta en una ubicación inmejorable**
#
# Vohome propiedades barajas vende piso en exclusiva.
#
# Descubre este encantador piso...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# Encontrado: 1/56
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Financiación 100%
#
#
#
#
#
#
#                         272.000 €
#
#
#
#
#
# Piso en calle de Campotejar
# Orcasur (Distrito Usera. Madrid Capital)
#
#
#
# 4 habs.
# 2 baños
# 113 m²
# 4ª planta
#
#
#
# Aaahora hminmobiliaria tiene tú casa en
#
# ¡Tú propiedad por menos de un alquiler! Compra tú piso y olvidate del alquiler!
# Ver vide...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# Encontrado: 1/43
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Urbanización privada
#
#
#
#
#
#
#                         208.000 €
#
#
#
#
#
# Piso en calle de Campezo
# Rejas (Distrito San Blas. Madrid Capital)
#
#
#
# 1 hab.
# 1 baño
# 46 m²
# 1ª planta
#
#
#
# Hminmobiliaria vende apartamento turístico y como vivienda habitual en ub. Cerrada, vigilancia 24h, garaje, piscina, padel, zona p...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# Encontrado: 1/30
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         420.000 €
#
#
#
#
#
# Piso en calle de Camarena
# Aluche (Distrito Latina. Madrid Capital)
#
#
#
# 4 habs.
# 2 baños
# 105 m²
# 1ª planta
#
#
#
# Masterpiso vende piso en calle camarena, aluche, madrid, 1ª planta, ascensor, 105 m² construidos, piso exterior, 4 habitaciones, c...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/13
#
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         242.550 €
#
# 11.550 € (-5%)
#
#
#
#
# Piso en calle del Espinar
# Vista Alegre (Distrito Carabanchel. Madrid Capital)
#
#
#
# 3 habs.
# 1 baño
# 97 m²
# 3ª planta
#
#
#
# Piso de 97 m² construidos, que se vende alquilado y al corriente de pago. Contrato de alquiler hasta febrero de 2027.
# Alquilado: o...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# Encontrado: 1/30
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         399.000 €
#
#
#
#
#
# Piso en calle del Concejal Francisco José Jiménez Martín
# Cármenes (Distrito Latina. Madrid Capital)
#
#
#
# 3 habs.
# 1 baño
# 127 m²
# Bajo
#
#
#
# Masterpiso vende piso en urbanización cerrada con video portero en la c/ concejal francisco josé jiménez martín, bajo con ascensor...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/13
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         180.000 €
#
#
#
#
#
# Piso en calle de Zurbarán
# Pintores-Ferial (Parla)
#
#
#
# 4 habs.
# 2 baños
# 120 m²
# Bajo
#
#
#
# Vendo local de 120 m² con fachada a 2 calles.
# Proyecto de 2 viviendas ajustadas a normativa.
# Proyecto visado y presentados en urba...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/15
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Negociable
#
#
#
#
#
#
#                         439.000 €
#
#
#
#
#
# Loft en calle de la Drácena
# Nueva España (Distrito Chamartín. Madrid Capital)
#
#
#
# 1 hab.
# 1 baño
# 69 m²
#
#
#
# Loft unico de 56 mts utiles escriturados(equivalente a 69 mts construidos) reformado integramente y amueblado por estudio arquitec...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/42
#
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         729.000 €
#
#
#
#
#
# Piso en Alameda de Osuna
# Alameda de Osuna (Distrito Barajas. Madrid Capital)
#
#
#
# 3 habs.
# 2 baños
# 130 m²
# 3ª planta
#
#
#
# Vohome propiedades barajas vende.
#
# Descubre este espectacular piso actualizado en 2023, ubicado en una de las zonas residenciales ...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# Encontrado: 1/21
#
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Reformado
#
#
#
#
#
#
#                         369.000 €
#
#
#
#
#
# Piso en calle de Nuestra Señora de Araceli
# Casco Histórico de Barajas (Distrito Barajas. Madrid Capital)
#
#
#
# 3 habs.
# 1 baño
# 75 m²
# Bajo
#
#
#
# Vohome propiedades barajas vende piso en exclusiva.
#
# **piso en venta en el encantador casco histórico de barajas**
#
# Descubre este ...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# Encontrado: 1/31
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         740.000 €
#
#
#
#
# Piso en Avenida de Niza
# Rosas (Distrito San Blas. Madrid Capital)
#
#
#
# 4 habs.
# 2 baños
# 137 m²
# 1ª planta
#
#
#
# Inmobiliaria en rejas, madrid - tecnocasa estudio rejas - las musas sl
#
# Vende en exclusiva espectacular piso de cuatro habitacione...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/29
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Visítalo
#
#
#
#
#
#
#                         205.000 €
#
#
#
#
#
# Piso en Avenida de los Reyes Católicos
# Puerta de Madrid, El Juncal (Distrito Reyes Católicos. Alcalá de Henares)
#
#
#
# 3 habs.
# 1 baño
# 80 m²
# 1ª planta
#
#
#
# Liderpiso inmobiliaria pone a la venta este hogar accesible, bien ubicado que se adaptará a las distintas etapas de tu vida.
# Si qu...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/13
#
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         195.460 €
#
# 19.540 € (-9%)
#
#
#
#
# Piso en Avenida de Roma
# Ciudad 70 (Coslada)
#
#
#
# 2 habs.
# 1 baño
# 89 m²
# 1ª planta
#
#
#
# Piso de 89 m² construidos, que se vende alquilado y al corriente de pago. Contrato de alquiler hasta julio de 2026.
# Con ascensor.
# ...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# Encontrado: 1/54
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Amplio
#
#
#
#
#
#
#                         514.900 €
#
# 16.100 € (-3%)
#
#
#
#
# Chalet adosado en calle del Río Bidasoa
# Rinconada (Distrito Reyes Católicos. Alcalá de Henares)
#
#
#
# 4 habs.
# 4 baños
# 210 m²
#
#
#
# Se vende chalet adosado en la zona de rinconada, en alcalá de henares. La propiedad cuenta con una superficie total de 209,78 m², ...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/24
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         2.600.000 €
#
#
#
#
#
# Ático en calle de María de Molina
# Castellana (Distrito Barrio de Salamanca. Madrid Capital)
#
#
#
# 2 habs.
# 3 baños
# 120 m²
#
#
#
# Este espectacular ático de lujo en venta presentado por studios y proyectos madrid, tiene el placer de presentar este exclusivo át...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/72
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Exclusivo
#
#
#
#
#
#
#                         990.000 €
#
#
#
#
#
# Casa adosada en calle de la Rosa de Lima, 9
# Club de Golf-Molino de la Hoz (Las Rozas de Madrid)
#
#
#
# 5 habs.
# 4 baños
# 300 m²
#
#
#
# ^^adosado a estrenar en las rozas de madrid | eficiencia energética, diseño moderno y máximo confort^^
#
# Te presentamos este magníf...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/35
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         409.000 €
#
#
#
#
#
# Chalet en calle Centro
# Lozoyuela (Lozoyuela-Navas-Sieteiglesias)
#
#
#
# 7 habs.
# 3 baños
# 222 m²
#
#
#
# Brem global inmobiliaria presenta chalet independiente en sieteiglesias, pedanía de lozoyuela. A 65 km de madrid y a dos minutos d...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/30
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         409.000 €
#
#
#
#
#
# Chalet en Carretera de Valdemanco
# La Cabrera
#
#
#
# 4 habs.
# 2 baños
# 300 m²
#
#
#
# Brem global inmobiliaria presenta amplio y luminoso chalet independiente en una urbanización cerrada en la cabrera construido sobr...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/47
#
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Exclusivo
#
#
#
#
#
#
#                         435.000 €
#
#
#
#
#
# Apartamento en calle N-A
# Palacio (Distrito Centro. Madrid Capital)
#
#
#
# 1 hab.
# 1 baño
# 40 m²
# 3ª planta
#
#
#
# ^**^glamour en el corazon de madrid, emblematico apartamento en el madrid de los austrias^**^
# Se vende un fabuloso apartamento de ...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/17
#
#
#
#
#
#
#
#
#
#
#
#
#                             Nuevo
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         340.000 €
#
#
#
#
#
# Piso en calle de Servando Batanero
# Ventas (Distrito Ciudad Lineal. Madrid Capital)
#
#
#
# 3 habs.
# 2 baños
# 92 m²
# 4ª planta
#
#
#
# Century 21 gallery presenta este encantador apartamento de 92m². Esta propiedad ofrece una excelente oportunidad de inversión en u...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
# Encontrado: 1/62
#
#
#
#
#
#
#
#
#
#
#
#
#                             Nuevo
#
#
#
# TOP
#
#
#
#
#
#
#                     Visítalo
#
#
#
#
#
#
#                         188.000 €
#
#
#
#
#
# Piso en calle de Campotejar
# Orcasur (Distrito Usera. Madrid Capital)
#
#
#
# 2 habs.
# 1 baño
# 83 m²
# 1ª planta
#
#
#
# Ahoraaa! Hminmobiliaria tiene tú casa, tú piso,. En c/ campotejar, 1º con ascensor! Para reformar a tu gusto y necesidad!
#
# ¡Tú pr...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# Encontrado: 1/10
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         183.000 €
#
#
#
#
#
# Piso en calle de la Sierra de Monchique
# San Diego (Distrito Puente de Vallecas. Madrid Capital)
#
#
#
# 3 habs.
# 1 baño
# 68 m²
# Bajo
#
#
#
# Inmueble okupado - oportunidad de inversión
#
# Imposibilidad de visita interior.
#
# Las fotografías pueden no corresponderse con el es...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# Encontrado: 1/42
#
#
#
#
#
#
#
#
#
#
#
# TOP
#
#
#
#
#
#
#                     Oportunidad
#
#
#
#
#
#
#                         1.850.000 €
#
#
#
#
#
# Chalet en Carretera de Húmera
# Aravaca (Distrito Moncloa-Aravaca. Madrid Capital)
#
#
#
# 4 habs.
# 5 baños
# 258 m²
#
#
#
# Vivir en una casa completamente renovada en 2025, con diseño contemporáneo, eficiencia energética de última generación y espacios ...
#
#
#
# Llamar
# Contactar
# Avísame si baja
# WhatsApp
